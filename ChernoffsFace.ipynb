# %%
 pip install ChernoffFace
# Out:
# Collecting ChernoffFace
#   Downloading ChernoffFace-0.1.4-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: numpy in c:\users\hari\anaconda3\lib\site-packages (from ChernoffFace) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\hari\anaconda3\lib\site-packages (from ChernoffFace) (3.8.0)
# Requirement already satisfied: pillow in c:\users\hari\anaconda3\lib\site-packages (from ChernoffFace) (10.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hari\anaconda3\lib\site-packages (from matplotlib->ChernoffFace) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hari\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ChernoffFace) (1.16.0)
# Downloading ChernoffFace-0.1.4-py3-none-any.whl (16 kB)
# Installing collected packages: ChernoffFace
# Successfully installed ChernoffFace-0.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from ChernoffFace import *
import numpy
import matplotlib.cm

# %%
# Generate data
numpy.random.seed(32)
data = numpy.random.rand(16, 12)

# Make Chernoff faces
fig = chernoff_face(data=data, 
                    titles=[str(x) for x in list(range(len(data)))], 
                    color_mapper=matplotlib.cm.Pastel1)

# Display
fig.tight_layout()
matplotlib.pyplot.show()

# %%
dfData=load_usa_arrests_data_frame()
dfData.head()
# Out:
#     StateName  Murder  Assault  UrbanPopulation  Rape
# 0     Alabama    13.2      236               58  21.2
# 1      Alaska    10.0      263               48  44.5
# 2     Arizona     8.1      294               80  31.0
# 3    Arkansas     8.8      190               50  19.5
# 4  California     9.0      276               91  40.6

# %%
fig = chernoff_face(data=dfData,
                    n_columns=5,
                    long_face=False,
                    color_mapper=matplotlib.cm.tab20c_r,
                    figsize=(8, 10), dpi=100)

fig.tight_layout()
matplotlib.pyplot.show()

# %%
#Employee Attitude
dfData=load_employee_attitude_data_frame()
dfData.head()
# Out:
#    Rating  Complaints  Privileges  Learning  Raises  Critical  Advancement
# 0      43          51          30        39      61        92           45
# 1      63          64          51        54      63        73           47
# 2      71          70          68        69      76        86           48
# 3      61          63          45        47      54        84           35
# 4      81          78          56        66      71        83           47

# %%
fig = chernoff_face(data=dfData,
                    n_columns=5,
                    long_face=False,
                    color_mapper=matplotlib.cm.tab20b,
                    figsize=(8, 8), dpi=100)
fig.tight_layout()
matplotlib.pyplot.show()
